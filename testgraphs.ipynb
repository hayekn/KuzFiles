# %% [markdown]
# ## Uniform State Var

# %%
import numpy as np
import matplotlib.pyplot as plt
#Plotting Seek and Setpoint
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,1)), label= 'Seek',  linewidth = '1.5')
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,6)), label= 'Setpoint',  linewidth = '1.5')
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,7)), label= 'State',  linewidth = '1.5')

plt.legend()
plt.xlabel('Time(t)')
plt.ylabel('Firing rate(Hz)')
plt.show()

#Plotting Binge and Stop Neurons
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,2)), label = 'Binge',  linewidth = '2.1')
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,3)), label = 'Stop', linewidth='2.1')

plt.legend()
plt.xlabel('Time(t)')
plt.ylabel('Firing rate(Hz)')
plt.show()

#Plotting STR and VTA
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,4)), label = 'STR', linewidth='2.1')
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,8)), label = 'VTA', linewidth='2.1')

plt.legend()
plt.xlabel('Time(t)')
plt.ylabel('Firing rate(Hz)')
plt.show()


#Plotting Alcohol Consumed
plt.plot(*np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/uniform_state.dat", unpack = True, usecols = (0,5)), label = 'Alcohol', linewidth = '2.2')
plt.legend()
plt.xlabel('Time (t)')
plt.ylabel('Consumption Rate')
# Out:
# Text(0, 0.5, 'Consumption Rate')

# %% [markdown]
# ## Looped State Variable

# %%
import numpy as np
import matplotlib.pyplot as plt
tfont = {'fontname':'Times New Roman'}

time = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (0))
seek = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (1))
setp = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (6))
binge = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (2))
stop = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (3))
striatum = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (4))
vta = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (8))
alc = np.loadtxt(r"/Users/amyrude/Downloads/IUPUI_REU/looped_tol15.dat", unpack = True, usecols = (5))

f, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0,0].axvline(x=15.9, color = 'silver',linestyle='dashed')
axs[0,0].plot(time, seek, label = 'Seek', color = 'midnightblue')
axs[0,0].plot(time, setp, label = 'Setpoint', color = 'royalblue')
axs[0,0].set_title('mPFC Activity', **tfont, fontweight = 'bold', fontsize='14')
axs[0,0].set_ylabel('Firing Rate (Hz)',**tfont, fontsize='12')
axs[0,0].set_xlabel('Time (s)',**tfont, fontsize='12')
axs[0,0].legend()

axs[0,1].axvline(x=15.9, color = 'silver',linestyle='dashed')
axs[0,1].plot(time, binge, label ='Binge', color = 'mediumseagreen')
axs[0,1].plot(time, stop, label = 'Stop', color = 'darkgreen')
axs[0,1].set_title('Insular Activity',**tfont, fontweight = 'bold', fontsize='14')
axs[0,1].set_ylabel('Firing Rate (Hz)',**tfont, fontsize='12')
axs[0,1].set_xlabel('Time (s)',**tfont, fontsize='12')
axs[0,1].legend()

axs[1,0].axvline(x=15.9, color = 'silver',linestyle='dashed')
axs[1,0].plot(time, vta, label = 'VTA', color = 'lightcoral')
axs[1,0].plot(time,striatum, label = 'Striatum', color = 'maroon')
axs[1,0].set_title('Striatum Activity',**tfont, fontweight = 'bold', fontsize='14')
axs[1,0].set_ylabel('Firing Rate (Hz)',**tfont, fontsize='12')
axs[1,0].set_xlabel('Time (s)',**tfont, fontsize='12')
axs[1,0].legend()

axs[1,1].axvline(x=15.9, color = 'silver',linestyle='dashed')
axs[1,1].plot(time, alc, color = 'red')
axs[1,1].set_title('Alcohol Consumed',**tfont, fontweight = 'bold', fontsize='14')
axs[1,1].set_ylabel('Volume (mL)',**tfont, fontsize='12')
axs[1,1].set_xlabel('Time (s)',**tfont, fontsize='12')

plt.subplots_adjust(wspace=0.2, hspace=0.3)
plt.show()

plt.figure(figsize=(15,5))
plt.plot(time, seek, label = 'Seek', color = 'midnightblue', linewidth='1.2')
plt.plot(time,setp, label = 'Setpoint', color = 'royalblue', linewidth='1.2')
plt.plot(time, binge, label ='Binge', color = 'mediumseagreen', linewidth='1.2')
plt.plot(time, stop, label = 'Stop', color = 'darkgreen', linewidth='1.2')
plt.plot(time, vta, label = 'VTA', color = 'lightcoral', linewidth='1.2')
plt.plot(time,striatum, label = 'Striatum', color = 'maroon', linewidth='1.2')
plt.xlabel('Time (s)',**tfont, fontsize='15',fontweight = 'bold')
plt.ylabel('Firing Rate (Hz)',**tfont, fontsize='15',fontweight = 'bold')
plt.legend()
plt.title('Simplified Model of Front-Loading',**tfont, fontweight = 'bold', fontsize='20')
# Out:
# Text(0.5, 1.0, 'Simplified Model of Front-Loading')
